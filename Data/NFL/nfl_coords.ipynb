# %%
import pandas as pd
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.sportsDB

# %%
coords_df = pd.read_csv('Stadium_Locations.csv')
coords_df
# Out:
#                TEAM NAME                    ref    LAT    LONG Unnamed: 4
# 0      Arizona Cardinals      Arizona Cardinals  33.27 -112.05        NaN
# 1        Atlanta Falcons        Atlanta Falcons  33.45  -84.23        NaN
# 2       Baltimore Ravens       Baltimore Ravens  39.17  -76.37        NaN
# 3          Buffalo Bills          Buffalo Bills  42.54  -78.53        NaN
# 4      Carolina Panthers      Carolina Panthers  35.14  -80.50        NaN
# 5          Chicago Bears          Chicago Bears  41.53  -87.38        NaN
# 6     Cincinnati Bengals     Cincinnati Bengals  39.06  -84.31        NaN
# 7       Cleveland Browns       Cleveland Browns  41.30  -81.41        NaN
# 8         Dallas Cowboys         Dallas Cowboys  32.47  -96.48        NaN
# 9         Denver Broncos         Denver Broncos  39.43 -105.01        NaN
# 10         Detroit Lions          Detroit Lions  42.20  -83.03        NaN
# 11     Green Bay Packers      Green Bay Packers  44.30  -88.01        NaN
# ...

# %%
coords_dict = coords_df.to_dict(orient='records')
coords_dict
# Out:
# [{'TEAM NAME': 'Arizona Cardinals',
#   'ref': ' Arizona Cardinals',
#   'LAT': 33.27,
#   'LONG': -112.05,
#   'Unnamed: 4': nan},
#  {'TEAM NAME': 'Atlanta Falcons',
#   'ref': ' Atlanta Falcons',
#   'LAT': 33.45,
#   'LONG': -84.23,
#   'Unnamed: 4': nan},
#  {'TEAM NAME': 'Baltimore Ravens',
#   'ref': ' Baltimore Ravens',
#   'LAT': 39.17,
#   'LONG': -76.37,
#   'Unnamed: 4': nan},
#  {'TEAM NAME': 'Buffalo Bills',
#   'ref': ' Buffalo Bills',
#   'LAT': 42.54,
#   'LONG': -78.53,
#   'Unnamed: 4': nan},
#  {'TEAM NAME': 'Carolina Panthers',
#   'ref': ' Carolina Panthers',
#   'LAT': 35.14,
#   'LONG': -80.5,
#   'Unnamed: 4': nan},
#  {'TEAM NAME': 'Chicago Bears',
#   'ref': ' Chicago Bears',
#   'LAT': 41.53,
#   'LONG': -87.38,
#   'Unnamed: 4': nan},
#  {'TEAM NAME': 'Cincinnati Bengals',
#   'ref': ' Cincinnati Bengals',
#   'LAT': 39.06,
#   'LONG': -84.31,
#   'Unnamed: 4': nan},
#  {'TEAM NAME': 'Cleveland Browns',
#   'ref': ' Cleveland Browns',
#   'LAT': 41.3,
# ...

# %%
coll = db.nflcoords
coll2 = db.nfliconcoords

# %%
coll.insert(coords_dict)
# Out:
# C:\Users\Will\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# [ObjectId('5c771dbb9ec56b4078429715'),
#  ObjectId('5c771dbb9ec56b4078429716'),
#  ObjectId('5c771dbb9ec56b4078429717'),
#  ObjectId('5c771dbb9ec56b4078429718'),
#  ObjectId('5c771dbb9ec56b4078429719'),
#  ObjectId('5c771dbb9ec56b407842971a'),
#  ObjectId('5c771dbb9ec56b407842971b'),
#  ObjectId('5c771dbb9ec56b407842971c'),
#  ObjectId('5c771dbb9ec56b407842971d'),
#  ObjectId('5c771dbb9ec56b407842971e'),
#  ObjectId('5c771dbb9ec56b407842971f'),
#  ObjectId('5c771dbb9ec56b4078429720'),
#  ObjectId('5c771dbb9ec56b4078429721'),
#  ObjectId('5c771dbb9ec56b4078429722'),
#  ObjectId('5c771dbb9ec56b4078429723'),
#  ObjectId('5c771dbb9ec56b4078429724'),
#  ObjectId('5c771dbb9ec56b4078429725'),
#  ObjectId('5c771dbb9ec56b4078429726'),
#  ObjectId('5c771dbb9ec56b4078429727'),
# ...

# %%
coll2.insert(coords_dict)
# Out:
# C:\Users\Will\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# [ObjectId('5c771dbb9ec56b4078429715'),
#  ObjectId('5c771dbb9ec56b4078429716'),
#  ObjectId('5c771dbb9ec56b4078429717'),
#  ObjectId('5c771dbb9ec56b4078429718'),
#  ObjectId('5c771dbb9ec56b4078429719'),
#  ObjectId('5c771dbb9ec56b407842971a'),
#  ObjectId('5c771dbb9ec56b407842971b'),
#  ObjectId('5c771dbb9ec56b407842971c'),
#  ObjectId('5c771dbb9ec56b407842971d'),
#  ObjectId('5c771dbb9ec56b407842971e'),
#  ObjectId('5c771dbb9ec56b407842971f'),
#  ObjectId('5c771dbb9ec56b4078429720'),
#  ObjectId('5c771dbb9ec56b4078429721'),
#  ObjectId('5c771dbb9ec56b4078429722'),
#  ObjectId('5c771dbb9ec56b4078429723'),
#  ObjectId('5c771dbb9ec56b4078429724'),
#  ObjectId('5c771dbb9ec56b4078429725'),
#  ObjectId('5c771dbb9ec56b4078429726'),
#  ObjectId('5c771dbb9ec56b4078429727'),
# ...
